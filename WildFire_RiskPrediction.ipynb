# %%
# !pip install geemap
# Out:
# Collecting geemap
#   Downloading geemap-0.35.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting bqplot (from geemap)
#   Downloading bqplot-0.12.44-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting colour (from geemap)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting earthengine-api>=1.0.0 (from geemap)
#   Downloading earthengine_api-1.4.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting eerepr>=0.0.4 (from geemap)
#   Downloading eerepr-0.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting folium>=0.17.0 (from geemap)
#   Downloading folium-0.19.4-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting geocoder (from geemap)
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting ipyevents (from geemap)
#   Downloading ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting ipyfilechooser>=0.6.0 (from geemap)
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet>=0.19.2 (from geemap)
#   Downloading ipyleaflet-0.19.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipytree (from geemap)
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting matplotlib (from geemap)
#   Downloading matplotlib-3.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from geemap) (2.1.2)
# Collecting pandas (from geemap)
#   Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting plotly (from geemap)
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting pyperclip (from geemap)
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyshp>=2.3.1 (from geemap)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Collecting python-box (from geemap)
#   Downloading python_box-7.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (8.0 kB)
# Collecting scooby (from geemap)
#   Downloading scooby-0.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting google-cloud-storage (from earthengine-api>=1.0.0->geemap)
#   Downloading google_cloud_storage-2.19.0-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting google-api-python-client>=1.12.1 (from earthengine-api>=1.0.0->geemap)
#   Downloading google_api_python_client-2.159.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=1.4.1 (from earthengine-api>=1.0.0->geemap)
#   Downloading google_auth-2.37.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-httplib2>=0.0.3 (from earthengine-api>=1.0.0->geemap)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting httplib2<1dev,>=0.9.2 (from earthengine-api>=1.0.0->geemap)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from earthengine-api>=1.0.0->geemap) (2.32.3)
# Collecting branca>=0.6.0 (from folium>=0.17.0->geemap)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting jinja2>=2.9 (from folium>=0.17.0->geemap)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting xyzservices (from folium>=0.17.0->geemap)
#   Downloading xyzservices-2024.9.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting ipywidgets (from ipyfilechooser>=0.6.0->geemap)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet>=0.19.2->geemap)
#   Downloading jupyter_leaflet-0.19.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet>=0.19.2->geemap)
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting traitlets>=4.3.0 (from bqplot->geemap)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->geemap)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->geemap)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->geemap)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting click (from geocoder->geemap)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting future (from geocoder->geemap)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ratelim (from geocoder->geemap)
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six (from geocoder->geemap)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->geemap)
#   Downloading contourpy-1.3.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->geemap)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->geemap)
#   Downloading fonttools-4.55.3-cp311-cp311-macosx_10_9_universal2.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->geemap)
#   Downloading kiwisolver-1.4.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->geemap) (24.1)
# Collecting pillow>=8 (from matplotlib->geemap)
#   Downloading pillow-11.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->geemap)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting tenacity>=6.2.0 (from plotly->geemap)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading google_api_core-2.24.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting comm>=0.1.3 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipython>=6.1.0 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading ipython-8.31.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium>=0.17.0->geemap)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage->earthengine-api>=1.0.0->geemap)
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.7.2 (from google-cloud-storage->earthengine-api>=1.0.0->geemap)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->earthengine-api>=1.0.0->geemap)
#   Downloading google_crc32c-1.6.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (2.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->earthengine-api>=1.0.0->geemap) (2024.7.4)
# Collecting decorator (from ratelim->geocoder->geemap)
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting pexpect>4.3 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading prompt_toolkit-3.0.48-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting typing_extensions>=4.6 (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading geemap-0.35.1-py2.py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 2.7 MB/s eta 0:00:002.8 MB/s eta 0:00:01
# Downloading earthengine_api-1.4.5-py3-none-any.whl (457 kB)
# Downloading eerepr-0.1.0-py3-none-any.whl (10 kB)
# Downloading folium-0.19.4-py2.py3-none-any.whl (110 kB)
# Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Downloading ipyleaflet-0.19.2-py3-none-any.whl (31 kB)
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Downloading bqplot-0.12.44-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 4.0 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Downloading ipyevents-2.0.2-py3-none-any.whl (101 kB)
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading matplotlib-3.10.0-cp311-cp311-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 6.4 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 10.7 MB/s eta 0:00:0031m10.7 MB/s eta 0:00:01
# Downloading python_box-7.3.1-cp311-cp311-macosx_10_9_universal2.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.8 MB/s eta 0:00:00
# Downloading scooby-0.10.0-py3-none-any.whl (18 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading contourpy-1.3.1-cp311-cp311-macosx_11_0_arm64.whl (254 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 11.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading google_api_python_client-2.159.0-py2.py3-none-any.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 12.1 MB/s eta 0:00:000:00:0136m0:00:01
# Downloading google_auth-2.37.0-py2.py3-none-any.whl (209 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading jupyter_leaflet-0.19.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-macosx_11_0_arm64.whl (65 kB)
# Downloading pillow-11.1.0-cp311-cp311-macosx_11_0_arm64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 12.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading xyzservices-2024.9.0-py3-none-any.whl (85 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading google_cloud_storage-2.19.0-py2.py3-none-any.whl (131 kB)
# Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading google_api_core-2.24.0-py3-none-any.whl (158 kB)
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.6.0-cp311-cp311-macosx_12_0_arm64.whl (30 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Downloading ipython-8.31.0-py3-none-any.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 9.6 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.2 MB/s eta 0:00:00
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.7 MB/s eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading prompt_toolkit-3.0.48-py3-none-any.whl (386 kB)
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
# Downloading protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.9 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11003 sha256=da64be976db4243e8f26faaba0753afb483582065234ca1ff71f12655226d60d
#   Stored in directory: /Users/pathak14/Library/Caches/pip/wheels/e8/e7/56/591cb88ba1783b38c40d584026e766aac9c3a048e34128ce8b
# Successfully built pyperclip
# Installing collected packages: wcwidth, pytz, pyperclip, pure-eval, ptyprocess, colour, xyzservices, widgetsnbextension, uritemplate, tzdata, typing_extensions, traitlets, tenacity, six, scooby, python-box, pyshp, pyparsing, pygments, pyasn1, protobuf, prompt_toolkit, pillow, pexpect, parso, MarkupSafe, kiwisolver, jupyterlab-widgets, jupyter-leaflet, google-crc32c, future, fonttools, executing, decorator, cycler, contourpy, click, cachetools, asttokens, traittypes, stack_data, rsa, ratelim, python-dateutil, pyasn1-modules, proto-plus, plotly, matplotlib-inline, jinja2, jedi, httplib2, googleapis-common-protos, google-resumable-media, comm, pandas, matplotlib, ipython, google-auth, geocoder, branca, ipywidgets, google-auth-httplib2, google-api-core, folium, ipytree, ipyleaflet, ipyfilechooser, ipyevents, google-cloud-core, google-api-python-client, bqplot, google-cloud-storage, earthengine-api, eerepr, geemap
# Successfully installed MarkupSafe-3.0.2 asttokens-3.0.0 bqplot-0.12.44 branca-0.8.1 cachetools-5.5.0 click-8.1.8 colour-0.1.5 comm-0.2.2 contourpy-1.3.1 cycler-0.12.1 decorator-5.1.1 earthengine-api-1.4.5 eerepr-0.1.0 executing-2.1.0 folium-0.19.4 fonttools-4.55.3 future-1.0.0 geemap-0.35.1 geocoder-1.38.1 google-api-core-2.24.0 google-api-python-client-2.159.0 google-auth-2.37.0 google-auth-httplib2-0.2.0 google-cloud-core-2.4.1 google-cloud-storage-2.19.0 google-crc32c-1.6.0 google-resumable-media-2.7.2 googleapis-common-protos-1.66.0 httplib2-0.22.0 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.19.2 ipython-8.31.0 ipytree-0.2.2 ipywidgets-8.1.5 jedi-0.19.2 jinja2-3.1.5 jupyter-leaflet-0.19.2 jupyterlab-widgets-3.0.13 kiwisolver-1.4.8 matplotlib-3.10.0 matplotlib-inline-0.1.7 pandas-2.2.3 parso-0.8.4 pexpect-4.9.0 pillow-11.1.0 plotly-5.24.1 prompt_toolkit-3.0.48 proto-plus-1.25.0 protobuf-5.29.3 ptyprocess-0.7.0 pure-eval-0.2.3 pyasn1-0.6.1 pyasn1-modules-0.4.1 pygments-2.19.1 pyparsing-3.2.1 pyperclip-1.9.0 pyshp-2.3.1 python-box-7.3.1 python-dateutil-2.9.0.post0 pytz-2024.2 ratelim-0.1.6 rsa-4.9 scooby-0.10.0 six-1.17.0 stack_data-0.6.3 tenacity-9.0.0 traitlets-5.14.3 traittypes-0.2.1 typing_extensions-4.12.2 tzdata-2024.2 uritemplate-4.1.1 wcwidth-0.2.13 widgetsnbextension-4.0.13 xyzservices-2024.9.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import geemap
#       2 import ee
#
# ModuleNotFoundError: No module named 'geemap'

# %%
import geemap
import ee
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Authenticate and Initialize GEE developper account
# Go to signup.earthengine.google.com to register an account
ee.Authenticate()
ee.Initialize()

# Declare new empty map
Map = geemap.Map()

# Select date range to retrieve images from
date_filt = ee.Filter.date('2020-06-01', '2020-07-01')

# Create a dataset consiting of MODIS bands, median is taken over selected filter
ds_modis = ee.ImageCollection("MODIS/006/MCD43A4") \
    .filter(date_filt)\
    .select(['Nadir_Reflectance_Band1', 'Nadir_Reflectance_Band2',
              'Nadir_Reflectance_Band3', 'Nadir_Reflectance_Band4',
              'Nadir_Reflectance_Band5', 'Nadir_Reflectance_Band6',
              'Nadir_Reflectance_Band7'])\
    .median()

# Select bands that correspond to RGB to see results on a map
trueColor = ds_modis.select(['Nadir_Reflectance_Band1', 'Nadir_Reflectance_Band4',
                            'Nadir_Reflectance_Band3'])

# Color parameters suggested by GEE
modis_vis = {
  'min': 0,
  'max': 4000.0,
  'gamma': 1.4,
}

# Add to map as a new layer
Map.addLayer(trueColor, modis_vis, 'MODIS')

# Display Map
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
import numpy as np
import rasterio
import os
from random import shuffle
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
dataset_txt= 'https://drive.google.com/uc?id=1MVmx927A4AUZksHqb3liW4lUf5ts9l6v'
labels = 'https://drive.google.com/uc?id=1Gq0VXTElJWWfCcwnxLxA5CVWuls0is-y'

# %%
# !gdown {dataset_txt}
# !gdown {labels}
# !unzip -oq labels

# !ls -la ./content/whp

# %%
# inspect label tile
# !gdalinfo ./content/whp/whp2014_target_tile_000.tif
# inspect train tile
# !gdalinfo /content/gdrive/MyDrive/ECE471-Final/TrainingSet/trainset2/2014-06:train_tile_000.tif

# %%
f = open('dataset.txt')
samples = [line.rstrip('\n') for line in f]
#samples = [x.split(" ") for x in samples]

# %%
print(samples)

# %%
with open('dataset.txt') as f2:
    full_string1 = ' '.join([line.strip() for line in f2])

# %%
print(full_string1)
